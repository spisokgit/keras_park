# %%
# Deep Learning Quick Reference Chapter 5: Multiclass Classification
# Mike Bernico <mike.bernico@gmail.com>

from keras.datasets import mnist
from keras.utils import to_categorical
from keras.models import Model
from keras.layers import Input, Dense, Dropout
from keras.callbacks import TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report
import numpy as np
import os
import matplotlib.pyplot as plt
# %matplotlib inline

def load_mnist():
    (train_X, train_y), (test_X, test_y) = mnist.load_data()
    train_X = train_X.reshape(-1, 784)
    test_X = test_X.reshape(-1, 784)
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    train_X /= 255
    test_X /= 255

    train_y = to_categorical(train_y)
    test_y = to_categorical(test_y)
    return {"train_X": train_X[:55000, :], "train_y": train_y[:55000, :],
            "val_X": train_X[55000:, :], "val_y": train_y[55000:, :], "test_X": test_X, "test_y": test_y}

def build_network(input_features=None):
    # first we specify an input layer, with a shape == features
    inputs = Input(shape=(input_features,), name="input")
    x = Dense(512, activation='relu', name="hidden1", kernel_regularizer='l2')(inputs)  ####################### L2 regularization
    x = Dense(256, activation='relu', name="hidden2", kernel_regularizer='l2')(x)
    x = Dense(128, activation='relu', name="hidden3", kernel_regularizer='l2')(x)
    prediction = Dense(10, activation='softmax', name="output")(x)
    model = Model(inputs=inputs, outputs=prediction)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=["accuracy"])
    return model

def create_callbacks():
    tensorboard_callback = TensorBoard(log_dir=os.path.join(os.getcwd(), "tb_log", "mnist_512_256_128_l2"), histogram_freq=1, batch_size=32,
                                       write_graph=True, write_grads=False)
    checkpoint_callback = ModelCheckpoint(filepath="./model-weights.{epoch:02d}-{val_accuracy:.6f}.hdf5", monitor='val_accuracy',
                                          verbose=0, save_best_only=True)
    return [tensorboard_callback, checkpoint_callback]

def print_model_metrics(model, data):
    loss, accuracy = model.evaluate(x=data["test_X"], y=data["test_y"])
    print("\n model test loss is "+str(loss)+" accuracy is "+str(accuracy))

    y_softmax = model.predict(data["test_X"])  # this is an n x class matrix of probabilities
    y_hat = y_softmax.argmax(axis=-1)  # this will be the class number.
    test_y = data["test_y"].argmax(axis=-1)  # our test data is also categorical
    print(classification_report(test_y, y_hat))

    # 영상입력 다중분류 모델사용하기(실제손글씨 판정결과 plt)   <======   model.add(Dense(10, activation='softmax'))
    width = 28
    height = 28
    plt_row = 5
    plt_col = 5
    plt.rcParams["figure.figsize"] = (10,10)
    f, axarr = plt.subplots(plt_row, plt_col)
    cnt = 0
    i = 0
    j = []
    while cnt < (plt_row*plt_col):
        if np.argmax(data["test_y"][i]) == np.argmax(y_softmax[i]):
            i += 1
            continue
        sub_plt = axarr[cnt//plt_row, cnt%plt_col]
        sub_plt.axis('off')
        sub_plt.imshow(data["test_X"][i].reshape(width, height))
        sub_plt_title = 'R: ' + str(np.argmax(data["test_y"][i])) + ' P: ' + str(np.argmax(y_softmax[i]))
        sub_plt.set_title(sub_plt_title)
        j.append(i)

        i += 1    
        cnt += 1

    print(f'\ntest {len(y_softmax)}중에서 틀린 개수 : {cnt}')
    print(f'틀린 index : {j}')

    plt.show()

    # 모델 학습과정 살펴보기
def plt_model_process(hist):
    fig, loss_ax = plt.subplots()
    acc_ax = loss_ax.twinx()
    loss_ax.plot(hist.history['loss'], 'y', label='train loss')
    loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
    loss_ax.set_ylim([0.0, 0.5])
    acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
    acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')
    acc_ax.set_ylim([0.8, 1.0])
    loss_ax.set_xlabel('epoch')
    loss_ax.set_ylabel('loss')
    acc_ax.set_ylabel('accuray')
    loss_ax.legend(loc='lower left')
    acc_ax.legend(loc='upper left')
    plt.show()
# Out:
# Using TensorFlow backend.

# %%
data = load_mnist()
callbacks = create_callbacks()
model = build_network(data["train_X"].shape[1])
hist=model.fit(x=data["train_X"], y=data["train_y"],
          batch_size=30,
          epochs=50,
          validation_data=(data["val_X"], data["val_y"]),
          verbose=1,
          callbacks=callbacks)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v2.py:92: UserWarning: The TensorBoard callback `batch_size` argument (for histogram computation) is deprecated with TensorFlow 2.0. It will be ignored.
#   warnings.warn('The TensorBoard callback `batch_size` argument '
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/50
# 55000/55000 [==============================] - 7s 128us/step - loss: 1.1247 - accuracy: 0.8856 - val_loss: 0.5687 - val_accuracy: 0.9486
# Epoch 2/50
# 55000/55000 [==============================] - 6s 114us/step - loss: 0.5939 - accuracy: 0.9197 - val_loss: 0.4895 - val_accuracy: 0.9442
# Epoch 3/50
# 55000/55000 [==============================] - 6s 110us/step - loss: 0.5134 - accuracy: 0.9303 - val_loss: 0.4401 - val_accuracy: 0.9522
# Epoch 4/50
# 55000/55000 [==============================] - 7s 118us/step - loss: 0.4642 - accuracy: 0.9371 - val_loss: 0.4068 - val_accuracy: 0.9542
# Epoch 5/50
# 55000/55000 [==============================] - 6s 114us/step - loss: 0.4341 - accuracy: 0.9412 - val_loss: 0.3793 - val_accuracy: 0.9570
# Epoch 6/50
# 55000/55000 [==============================] - 7s 133us/step - loss: 0.4110 - accuracy: 0.9439 - val_loss: 0.3980 - val_accuracy: 0.9462
# Epoch 7/50
# 55000/55000 [==============================] - 6s 114us/step - loss: 0.4014 - accuracy: 0.9449 - val_loss: 0.3528 - val_accuracy: 0.9578
# Epoch 8/50
# 55000/55000 [==============================] - 6s 111us/step - loss: 0.3908 - accuracy: 0.9444 - val_loss: 0.3410 - val_accuracy: 0.9602
# Epoch 9/50
# 55000/55000 [==============================] - 7s 136us/step - loss: 0.3837 - accuracy: 0.9445 - val_loss: 0.3490 - val_accuracy: 0.9602
# Epoch 10/50
# 55000/55000 [==============================] - 7s 125us/step - loss: 0.3737 - accuracy: 0.9467 - val_loss: 0.3522 - val_accuracy: 0.9558
# Epoch 11/50
# 55000/55000 [==============================] - 7s 132us/step - loss: 0.3666 - accuracy: 0.9486 - val_loss: 0.3135 - val_accuracy: 0.9652
# Epoch 12/50
# 55000/55000 [==============================] - 6s 114us/step - loss: 0.3611 - accuracy: 0.9485 - val_loss: 0.3191 - val_accuracy: 0.9626
# Epoch 13/50
# 55000/55000 [==============================] - 6s 114us/step - loss: 0.3579 - accuracy: 0.9481 - val_loss: 0.3201 - val_accuracy: 0.9616
# Epoch 14/50
# 55000/55000 [==============================] - 7s 121us/step - loss: 0.3550 - accuracy: 0.9487 - val_loss: 0.3183 - val_accuracy: 0.9616
# Epoch 15/50
# 55000/55000 [==============================] - 7s 129us/step - loss: 0.3511 - accuracy: 0.9482 - val_loss: 0.3100 - val_accuracy: 0.9656
# Epoch 16/50
# 55000/55000 [==============================] - 7s 119us/step - loss: 0.3462 - accuracy: 0.9491 - val_loss: 0.3075 - val_accuracy: 0.9640
# Epoch 17/50
# 55000/55000 [==============================] - 6s 103us/step - loss: 0.3428 - accuracy: 0.9491 - val_loss: 0.3083 - val_accuracy: 0.9624
# Epoch 18/50
# 55000/55000 [==============================] - 7s 119us/step - loss: 0.3428 - accuracy: 0.9490 - val_loss: 0.3272 - val_accuracy: 0.9574
# Epoch 19/50
# 55000/55000 [==============================] - 6s 116us/step - loss: 0.3399 - accuracy: 0.9494 - val_loss: 0.3275 - val_accuracy: 0.9540
# Epoch 20/50
# 55000/55000 [==============================] - 6s 117us/step - loss: 0.3375 - accuracy: 0.9495 - val_loss: 0.2990 - val_accuracy: 0.9624
# Epoch 21/50
# 55000/55000 [==============================] - 6s 110us/step - loss: 0.3359 - accuracy: 0.9495 - val_loss: 0.2885 - val_accuracy: 0.9662
# Epoch 22/50
# 55000/55000 [==============================] - 8s 146us/step - loss: 0.3353 - accuracy: 0.9496 - val_loss: 0.2982 - val_accuracy: 0.9644
# Epoch 23/50
# 55000/55000 [==============================] - 6s 106us/step - loss: 0.3305 - accuracy: 0.9497 - val_loss: 0.3066 - val_accuracy: 0.9562
# Epoch 24/50
# 55000/55000 [==============================] - 7s 127us/step - loss: 0.3297 - accuracy: 0.9499 - val_loss: 0.2988 - val_accuracy: 0.9636
# Epoch 25/50
# 55000/55000 [==============================] - 6s 109us/step - loss: 0.3290 - accuracy: 0.9500 - val_loss: 0.2890 - val_accuracy: 0.9630
# Epoch 26/50
# 55000/55000 [==============================] - 6s 114us/step - loss: 0.3296 - accuracy: 0.9496 - val_loss: 0.3425 - val_accuracy: 0.9450
# Epoch 27/50
# 55000/55000 [==============================] - 6s 117us/step - loss: 0.3253 - accuracy: 0.9512 - val_loss: 0.2861 - val_accuracy: 0.9638
# Epoch 28/50
# 55000/55000 [==============================] - 6s 108us/step - loss: 0.3266 - accuracy: 0.9498 - val_loss: 0.2871 - val_accuracy: 0.9612
# Epoch 29/50
# 55000/55000 [==============================] - 6s 117us/step - loss: 0.3242 - accuracy: 0.9505 - val_loss: 0.2949 - val_accuracy: 0.9608
# Epoch 30/50
# 55000/55000 [==============================] - 5s 95us/step - loss: 0.3220 - accuracy: 0.9510 - val_loss: 0.2840 - val_accuracy: 0.9636
# Epoch 31/50
# 55000/55000 [==============================] - 6s 101us/step - loss: 0.3225 - accuracy: 0.9496 - val_loss: 0.3015 - val_accuracy: 0.9614
# Epoch 32/50
# 55000/55000 [==============================] - 5s 99us/step - loss: 0.3208 - accuracy: 0.9511 - val_loss: 0.3073 - val_accuracy: 0.9554
# Epoch 33/50
# 55000/55000 [==============================] - 6s 104us/step - loss: 0.3210 - accuracy: 0.9501 - val_loss: 0.2964 - val_accuracy: 0.9592
# Epoch 34/50
# 55000/55000 [==============================] - 5s 95us/step - loss: 0.3191 - accuracy: 0.9499 - val_loss: 0.2917 - val_accuracy: 0.9600
# Epoch 35/50
# 55000/55000 [==============================] - 6s 103us/step - loss: 0.3177 - accuracy: 0.9503 - val_loss: 0.2949 - val_accuracy: 0.9574
# Epoch 36/50
# 55000/55000 [==============================] - 7s 121us/step - loss: 0.3155 - accuracy: 0.9512 - val_loss: 0.2703 - val_accuracy: 0.9634
# Epoch 37/50
# 55000/55000 [==============================] - 5s 99us/step - loss: 0.3163 - accuracy: 0.9507 - val_loss: 0.2862 - val_accuracy: 0.9628
# Epoch 38/50
# 55000/55000 [==============================] - 6s 106us/step - loss: 0.3170 - accuracy: 0.9510 - val_loss: 0.2784 - val_accuracy: 0.9636
# Epoch 39/50
# 55000/55000 [==============================] - 6s 105us/step - loss: 0.3148 - accuracy: 0.9513 - val_loss: 0.2991 - val_accuracy: 0.9588
# Epoch 40/50
# 55000/55000 [==============================] - 7s 120us/step - loss: 0.3166 - accuracy: 0.9496 - val_loss: 0.2770 - val_accuracy: 0.9646
# Epoch 41/50
# 55000/55000 [==============================] - 6s 109us/step - loss: 0.3135 - accuracy: 0.9519 - val_loss: 0.2644 - val_accuracy: 0.9668
# Epoch 42/50
# 55000/55000 [==============================] - 6s 103us/step - loss: 0.3119 - accuracy: 0.9512 - val_loss: 0.3105 - val_accuracy: 0.9544
# Epoch 43/50
# 55000/55000 [==============================] - 6s 107us/step - loss: 0.3116 - accuracy: 0.9512 - val_loss: 0.2724 - val_accuracy: 0.9682
# Epoch 44/50
# 55000/55000 [==============================] - 6s 108us/step - loss: 0.3111 - accuracy: 0.9505 - val_loss: 0.2755 - val_accuracy: 0.9624
# Epoch 45/50
# 55000/55000 [==============================] - 5s 99us/step - loss: 0.3098 - accuracy: 0.9515 - val_loss: 0.3628 - val_accuracy: 0.9326
# Epoch 46/50
# 55000/55000 [==============================] - 6s 110us/step - loss: 0.3112 - accuracy: 0.9505 - val_loss: 0.2747 - val_accuracy: 0.9632
# Epoch 47/50
# 55000/55000 [==============================] - 5s 96us/step - loss: 0.3097 - accuracy: 0.9514 - val_loss: 0.2816 - val_accuracy: 0.9622
# Epoch 48/50
# 55000/55000 [==============================] - 5s 97us/step - loss: 0.3096 - accuracy: 0.9513 - val_loss: 0.2813 - val_accuracy: 0.9602
# Epoch 49/50
# 55000/55000 [==============================] - 5s 99us/step - loss: 0.3097 - accuracy: 0.9511 - val_loss: 0.2644 - val_accuracy: 0.9672
# Epoch 50/50
# 55000/55000 [==============================] - 6s 100us/step - loss: 0.3064 - accuracy: 0.9522 - val_loss: 0.2833 - val_accuracy: 0.9596

# %%
plt_model_process(hist)

# %%
print_model_metrics(model, data)
# Out:
# 10000/10000 [==============================] - 0s 29us/step
#
#  model test loss is 0.3133446047306061 accuracy is 0.9470000267028809
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       980
#            1       0.98      0.98      0.98      1135
#            2       0.99      0.88      0.93      1032
#            3       0.94      0.92      0.93      1010
#            4       0.95      0.97      0.96       982
#            5       0.89      0.97      0.93       892
#            6       0.92      0.97      0.95       958
#            7       0.98      0.92      0.95      1028
#            8       0.92      0.94      0.93       974
#            9       0.92      0.95      0.94      1009
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
#
#
# test 10000중에서 틀린 개수 : 25
# 틀린 index : [8, 18, 33, 38, 87, 119, 124, 149, 217, 245, 247, 259, 290, 300, 313, 321, 324, 326, 341, 362, 444, 445, 448, 449, 495]
